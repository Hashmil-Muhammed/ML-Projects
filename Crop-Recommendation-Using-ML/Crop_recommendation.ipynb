# %% [markdown]
# **Good morning. Today, I'm excited to present my project focused on optimizing agriculture through machine learning-based crop recommendation. Agriculture's success relies on smart crop choices, and our system aims to assist farmers in making informed decisions based on environmental factors like soil nutrients, temperature, humidity, pH, and rainfall.**

# %% [markdown]
# and lest start

# %% [markdown]
# # **Importing libraries**

# %% [markdown]
# ***Imports necessary libraries for the project, including pandas, numpy, scikit-learn modules, and visualization libraries like matplotlib and seaborn.***

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# In this cell, essential libraries for data manipulation, visualization, and
# machine learning are imported. These include pandas, numpy, scikit-learn
# for machine learning algorithms, and various visualization libraries such
# as matplotlib and seaborn.

# %% [markdown]
# # **Loading data**

# %% [markdown]
# ***Loads the dataset (Crop_recommendation.csv) using pandas. The path to the file is specified***

# %%
# df=pd.read_csv('/content/Crop_recommendation.csv')
df=pd.read_csv(rf'G:\My Drive\Google colab\Projects\Project2\Crop_recommendation.csv')
df
# The dataset containing information about environmental conditions and
# crop labels is loaded from a GoogleCoalb file path.
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %% [markdown]
# The dataset above allow the users to build a predictive model to recommend the most suitable crops to grow in a particular farm based on various parameters.

# %% [markdown]
# Data fields:
#
# * N - ratio of Nitrogen content in soil
# * P - ratio of Phosphorous content in soil
# * K - ratio of Potassium content in soil
# * temperature - temperature in degree Celsius
# * humidity - relative humidity in %
# * ph - ph value of the soil
# * rainfall - rainfall in mm

# %% [markdown]
# ***Prints the shape of the dataset, indicating the number of rows and columns.***

# %%
print("Shape of the Dataset :",df.shape)
# Out:
# Shape of the Dataset : (2200, 8)

# %% [markdown]
# ***Lets Checks for any missing values in the dataset.***

# %%
df.isna().sum()
# No missing values found in any column.
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# ***Prints the data types of each column in the dataset.***

# %%
df.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %% [markdown]
# ***Prints the count of unique values in the 'label' column, representing the different crops.***

# %%
df['label'].value_counts()
# This means that the dataset is balanced.
# because each class has the same number of instances
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %% [markdown]
# not a imbalanced DS

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ***Groups the dataset by crop label and calculates the mean values for each feature.***

# %%
grouped = df.groupby(by='label').mean().reset_index()
grouped
# table for each crop, summarizing the average values of each
# feature for different crops. is displayed
# Out:
#           label       N       P       K  temperature   humidity        ph  \
# 0         apple   20.80  134.22  199.89    22.630942  92.333383  5.929663
# 1        banana  100.23   82.01   50.05    27.376798  80.358123  5.983893
# 2     blackgram   40.02   67.47   19.24    29.973340  65.118426  7.133952
# 3      chickpea   40.09   67.79   79.92    18.872847  16.860439  7.336957
# 4       coconut   21.98   16.93   30.59    27.409892  94.844272  5.976562
# 5        coffee  101.20   28.74   29.94    25.540477  58.869846  6.790308
# 6        cotton  117.77   46.24   19.56    23.988958  79.843474  6.912675
# 7        grapes   23.18  132.53  200.11    23.849575  81.875228  6.025937
# 8          jute   78.40   46.86   39.99    24.958376  79.639864  6.732778
# 9   kidneybeans   20.75   67.54   20.05    20.115085  21.605357  5.749411
# 10       lentil   18.77   68.36   19.41    24.509052  64.804785  6.927932
# 11        maize   77.76   48.44   19.79    22.389204  65.092249  6.245190
# ...

# %% [markdown]
# ***Prints the top 5 crops requiring the most of each feature.***

# %%
print(f'********************************')
for i in grouped.columns[1:]:
    print(f'Top 5 Most {i} requiring crops:')
    print(f'********************************')
    for j ,k in grouped.sort_values(by=i,ascending=False)[:5][['label',i]].values:
        print(f'{j} --> {k}')
    print(f'********************************')
#Top 5 crops requiring the most of each agricultural condition(based on mean values)
# are displayed.
# Out:
# ********************************
# Top 5 Most N requiring crops:
# ********************************
# cotton --> 117.77
# coffee --> 101.2
# muskmelon --> 100.32
# banana --> 100.23
# watermelon --> 99.42
# ********************************
# Top 5 Most P requiring crops:
# ********************************
# apple --> 134.22
# grapes --> 132.53
# banana --> 82.01
# lentil --> 68.36
# chickpea --> 67.79
# ********************************
# Top 5 Most K requiring crops:
# ********************************
# grapes --> 200.11
# apple --> 199.89
# chickpea --> 79.92
# watermelon --> 50.22
# muskmelon --> 50.08
# ********************************
# Top 5 Most temperature requiring crops:
# ********************************
# papaya --> 33.7238587388
# mango --> 31.2087701513
# blackgram --> 29.9733396789
# muskmelon --> 28.663065756
# mungbean --> 28.5257747353
# ********************************
# Top 5 Most humidity requiring crops:
# ********************************
# ...

# %% [markdown]
# ***Plots a heatmap to visualize the correlation matrix of the dataset.***

# %%
sns.heatmap(df.corr(),annot=True)
# A heatmap of the correlation matrix is created to visualize
# the relationships between different environmental factors.
# Out:
# <Axes: >

# %% [markdown]
# ***Creates a pair plot to explore relationships between different features in the dataset, with different colors for each crop.***

# %%
sns.pairplot(df,hue = 'label')
# A pair plot is displayed, showing relationships between numeric
# features for different crops.
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ***Creates bar plots to visualize the impact of different conditions on crops, including Nitrogen, Phosphorous, Potassium, Temperature, Humidity, pH, and Rainfall.***

# %%
plt.figure(layout='constrained')
plt.rcParams['figure.figsize'] = (15, 8)

plt.subplot(2, 4, 1)
sns.barplot(x='N', y='label', data=df)
plt.xlabel('Ratio of Nitrogen', fontsize=10)
plt.yticks(fontsize=10)

plt.subplot(2, 4, 2)
sns.barplot(x='P', y='label', data=df)
plt.xlabel('Ratio of Phosphorous', fontsize=10)
plt.yticks(fontsize=10)

plt.subplot(2, 4, 3)
sns.barplot(x='K', y='label', data=df)
plt.xlabel('Ratio of Potassium', fontsize=10)
plt.yticks(fontsize=10)

plt.subplot(2, 4, 4)
sns.barplot(x='temperature', y='label', data=df)
plt.xlabel('Temperature', fontsize=10)
plt.yticks(fontsize=10)

plt.subplot(2, 4, 5)
sns.barplot(x='humidity', y='label', data=df)
plt.xlabel('Humidity', fontsize=10)
plt.yticks(fontsize=10)

plt.subplot(2, 4, 6)
sns.barplot(x='ph', y='label', data=df)
plt.xlabel('pH of Soil', fontsize=10)
plt.yticks(fontsize=10)

plt.subplot(2, 4, 7)
sns.barplot(x='rainfall', y='label', data=df)
plt.xlabel('Rainfall', fontsize=10)
plt.yticks(fontsize=10)

plt.suptitle('Visualizing the Impact of Different Conditions on Crops', fontsize=15)
plt.tight_layout()
plt.show()
# Subplots displaying bar plots for the impact of conditions
# on crops are shown.

# %% [markdown]
# ***Plots a count plot to show the distribution of different crops.***

# %%
plt.figure(figsize=(15, 5))
sns.countplot(x='label', data=df)
plt.xticks(rotation=90)
plt.show()
# A count plot displaying the distribution of crop labels is shown.

# %% [markdown]
# ***Uses histograms, violin plots, and boxplots to visualize the distribution of each feature.***

# %%
plt.style.use('fast')
sns.set_palette("Set2")
for i in df.columns[:-1]:
    fig,ax=plt.subplots(1,3,figsize=(18,4))
    sns.histplot(data=df,x=i,kde=True,bins=20,ax=ax[0])
    sns.violinplot(data=df,x=i,ax=ax[1])
    sns.boxplot(data=df,x=i,ax=ax[2])
    plt.suptitle(f'Visualizing {i}',size=20)
  # Histograms, violin plots, and box plots for each feature are displayed.

# %% [markdown]
# # **Seperating features and target label**

# %% [markdown]
# ***Prints the unique crop labels in the 'label' column.***

# %%
df['label'].unique()
# Unique crop labels are displayed.
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %% [markdown]
# ***Uses LabelEncoder to convert crop labels to numerical values.***

# %%
le=LabelEncoder()
df['label']=le.fit_transform(df['label'])
df
# The Column 'label' converting crop names to corresponding numeric values using
# the LabelEncoder
# Out:
#         N   P   K  temperature   humidity        ph    rainfall  label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536     20
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537     20
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248     20
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034     20
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340     20
# ...   ...  ..  ..          ...        ...       ...         ...    ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507      5
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610      5
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839      5
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293      5
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041      5
#
# [2200 rows x 8 columns]

# %% [markdown]
# ***Prints the unique numerical values in the 'label' column.***

# %%
df['label'].unique()
# Unique LabelEncoder labels for the 'label' column are displayed.
# Out:
# array([20, 11,  3,  9, 18, 13, 14,  2, 10, 19,  1, 12,  7, 21, 15,  0, 16,
#        17,  4,  6,  8,  5])

# %% [markdown]
# ***Defines X (features) and y (target) based on the dataset.***

# %%
X = df.iloc[:,:-1]
y = df["label"]
# Features (X) and target variable (y) are created

print("Shape of X:",X.shape)
print("Shape of y:",y.shape)
# and their shapes are displayed.
# Out:
# Shape of X: (2200, 7)
# Shape of y: (2200,)

# %% [markdown]
# ***Splits the dataset into training and testing sets, and applies Min-Max scaling to normalize the feature values.***

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)
# Training and testing sets are created
scaler=MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# features are scaled
print("Shape of X train:",X_train.shape)
print("Shape of y train:",y_train.shape)
print("Shape of X test:",X_test.shape)
print("Shape of y test:",y_test.shape)
# and shapes are displayed.
# Out:
# Shape of X train: (1540, 7)
# Shape of y train: (1540,)
# Shape of X test: (660, 7)
# Shape of y test: (660,)

# %% [markdown]
# # **Modeling Classification algorithms**

# %% [markdown]
# ***Defines and fits machine learning models (KNeighborsClassifier, SVC, GaussianNB, DecisionTreeClassifier, RandomForestClassifier, LogisticRegression) to the training data.***

# %%
# lets create a Predictive Models
knn=KNeighborsClassifier()
sv=SVC()
nb=GaussianNB()
dt=DecisionTreeClassifier(random_state=1,criterion= 'gini', max_depth= 9)
rf=RandomForestClassifier(random_state=1)
lr=LogisticRegression(C=100)

models=[knn,sv,nb,dt,rf,lr]
for model in models:
    print("*"*25,model,"*"*25)
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    print(classification_report(y_pred,y_test))
  # Classification reports for each model on the test set are displayed.
# Out:
# ************************* KNeighborsClassifier() *************************
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       1.00      1.00      1.00        28
#            2       1.00      0.91      0.95        32
#            3       1.00      1.00      1.00        28
#            4       1.00      1.00      1.00        25
#            5       1.00      1.00      1.00        28
#            6       1.00      0.97      0.99        37
#            7       1.00      1.00      1.00        44
#            8       0.97      0.89      0.93        35
#            9       1.00      1.00      1.00        33
#           10       0.96      0.90      0.93        29
#           11       0.96      1.00      0.98        27
#           12       1.00      0.97      0.98        33
#           13       0.85      1.00      0.92        28
#           14       1.00      1.00      1.00        33
# ...

# %% [markdown]
# **From the Above Accuracies, We have adopt RandomForestClassifier,GaussianNB,DecisionTreeClassifier as it has Maximum Accuracy**

# %% [markdown]
# # **Accuracy comparison**

# %% [markdown]
# ***Evaluates and compares the accuracy of different machine learning models on the test set.***

# %%
acc = [model.score(X_test, y_test) for model in models]
df1 = pd.DataFrame({'Algorithm': [model.__class__.__name__ for model in models], 'Accuracy': acc})
df1['Accuracy'] = df1['Accuracy'].round(2)
df1 = df1.sort_values(by='Accuracy', ascending=False)
df1
# the Output testset using to comparing the accuracy of different algorithms is displayed.
# Out:
#                 Algorithm  Accuracy
# 2              GaussianNB      1.00
# 3  DecisionTreeClassifier      1.00
# 4  RandomForestClassifier      1.00
# 1                     SVC      0.99
# 0    KNeighborsClassifier      0.98
# 5      LogisticRegression      0.98

# %% [markdown]
# ***Plots a bar chart comparing the accuracy of different models, with vertical lines highlighting specific accuracy values.***

# %%
plt.figure(figsize=(10, 6))
plt.title('Accuracy Comparison',fontsize = 25)
plt.xlabel('Accuracy',fontsize = 15)
plt.ylabel('Algorithm',fontsize = 15)
sns.barplot(x='Accuracy', y='Algorithm', data=df1, palette='dark')

plt.axvline(x=1.0, color='black', linestyle='--')
plt.axvline(x=0.99, color='black', linestyle='--', ymin=0.001, ymax=0.48)
plt.axvline(x=0.98, color='black', linestyle='--', ymin=0.0, ymax=0.32)

plt.xticks([i/10 for i in range(11)])
plt.savefig('plot.png', dpi=300, bbox_inches='tight')
plt.show()
# A bar plot comparing the accuracy of different algorithms is displayed.

# %% [markdown]
# # **Making a prediction**

# %% [markdown]
# ***Uses selected models (Naive Bayes, Decision Tree, RandomForest) to make predictions for new climatic conditions and suggests a crop based on the predictions.***

# %%
model_pred=[nb,dt,rf]
for model in model_pred:
    print("*"*25,model,"*"*25)
    y_new = np.array([[20, 30, 10, 15, 90, 7.5, 100]])
    # y_new = np.array([[90,42,43,20.879744,82.002744,6.502985,202.935536]])
    new_pred = scaler.transform(y_new)
    new_pred1 = model.predict(new_pred)
    prediction = le.inverse_transform(new_pred1)
    print("The Suggested Crop for Given Climatic Condition is:", prediction)
    print()
# Out:
# ************************* GaussianNB() *************************
# The Suggested Crop for Given Climatic Condition is: ['orange']
#
# ************************* DecisionTreeClassifier(max_depth=9, random_state=1) *************************
# The Suggested Crop for Given Climatic Condition is: ['orange']
#
# ************************* RandomForestClassifier(random_state=1) *************************
# The Suggested Crop for Given Climatic Condition is: ['orange']

# %% [markdown]
# **Our Predictive Model works very well.
# This Predictive model is usefull for Modern Farming**
#
# In this output, the suggested crop for the given climatic condition is displayed for each model. For example, the Gaussian Naive Bayes model, the Decision Tree model, and the Random Forest model all suggest 'orange' as the crop for the specified climatic conditions. Each model's prediction is presented in the format of a list containing the predicted crop.

# %% [markdown]
# The Crop Recommendation System strives to empower farmers with data-driven insights, facilitating informed decisions and optimized agricultural practices. We look forward to continuous improvement and feature integration in the future.

# %%
# this is my Machine Learning Project
# i want to present the Project cell base using cell number you have to give me
# cell base code output description for my Machine Learning Project

# cell 1:
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import MinMaxScaler
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.svm import SVC
# from sklearn.naive_bayes import GaussianNB
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import classification_report
# import matplotlib.pyplot as plt
# import seaborn as sns
# import warnings
# warnings.filterwarnings('ignore')

# cell 2
# # df=pd.read_csv('/content/Crop_recommendation.csv')     #on google drive
# df=pd.read_csv(rf'G:\My Drive\Google colab\Projects\Project2\Crop_recommendation.csv')
# df

# cell 3
# print("Shape of the Dataset :",df.shape)

# cell 4
# df.isna().sum()

# cell 5
# df.dtypes

# cell 6
# df['label'].value_counts()

# cell 7
# grouped = df.groupby(by='label').mean().reset_index()
# grouped

# cell 8
# print(f'********************************')
# for i in grouped.columns[1:]:
#     print(f'Top 5 Most {i} requiring crops:')
#     print(f'********************************')
#     for j ,k in grouped.sort_values(by=i,ascending=False)[:5][['label',i]].values:
#         print(f'{j} --> {k}')
#     print(f'********************************')

# cell 9
# sns.heatmap(df.corr(),annot=True)

# cell 10
# sns.pairplot(df,hue = 'label')

# cell 11
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.figure(layout='constrained')
# plt.rcParams['figure.figsize'] = (15, 8)
# plt.subplot(2, 4, 1)
# sns.barplot(x='N', y='label', data=df)
# plt.xlabel('Ratio of Nitrogen', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 2)
# sns.barplot(x='P', y='label', data=df)
# plt.xlabel('Ratio of Phosphorous', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 3)
# sns.barplot(x='K', y='label', data=df)
# plt.xlabel('Ratio of Potassium', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 4)
# sns.barplot(x='temperature', y='label', data=df)
# plt.xlabel('Temperature', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 5)
# sns.barplot(x='humidity', y='label', data=df)
# plt.xlabel('Humidity', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 6)
# sns.barplot(x='ph', y='label', data=df)
# plt.xlabel('pH of Soil', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 7)
# sns.barplot(x='rainfall', y='label', data=df)
# plt.xlabel('Rainfall', fontsize=10)
# plt.yticks(fontsize=10)
# plt.suptitle('Visualizing the Impact of Different Conditions on Crops', fontsize=15)
# plt.show()


# cell 12
# plt.figure(layout='constrained')
# plt.rcParams['figure.figsize'] = (15, 8)
# plt.subplot(2, 4, 1)
# sns.barplot(x='N', y='label', data=df)
# plt.xlabel('Ratio of Nitrogen', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 2)
# sns.barplot(x='P', y='label', data=df)
# plt.xlabel('Ratio of Phosphorous', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 3)
# sns.barplot(x='K', y='label', data=df)
# plt.xlabel('Ratio of Potassium', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 4)
# sns.barplot(x='temperature', y='label', data=df)
# plt.xlabel('Temperature', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 5)
# sns.barplot(x='humidity', y='label', data=df)
# plt.xlabel('Humidity', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 6)
# sns.barplot(x='ph', y='label', data=df)
# plt.xlabel('pH of Soil', fontsize=10)
# plt.yticks(fontsize=10)
# plt.subplot(2, 4, 7)
# sns.barplot(x='rainfall', y='label', data=df)
# plt.xlabel('Rainfall', fontsize=10)
# plt.yticks(fontsize=10)
# plt.suptitle('Visualizing the Impact of Different Conditions on Crops', fontsize=15)
# plt.show()

# cell 13
# plt.figure(figsize=(15, 5))
# sns.countplot(x='label', data=df)  # Remove the palette parameter
# plt.xticks(rotation=90)
# plt.show()

# cell 14
# plt.style.use('fast')
# sns.set_palette("Set2")
# for i in df.columns[:-1]:
#     fig,ax=plt.subplots(1,3,figsize=(18,4))
#     sns.histplot(data=df,x=i,kde=True,bins=20,ax=ax[0])
#     sns.violinplot(data=df,x=i,ax=ax[1])
#     sns.boxplot(data=df,x=i,ax=ax[2])
#     plt.suptitle(f'Visualizing {i}',size=20)

# cell 20
# df['label'].unique()

# cell 21
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# df['label']=le.fit_transform(df['label'])
# df

# cell 22
# df['label'].unique()

# cell 23
# X = df.iloc[:,:-1]
# y = df["label"]
# print("Shape of X:",X.shape)
# print("Shape of y:",y.shape)

# cell 24
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)
# scaler=MinMaxScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
# print("Shape of X train:",X_train.shape)
# print("Shape of y train:",y_train.shape)
# print("Shape of X test:",X_test.shape)
# print("Shape of y test:",y_test.shape)

# cell 25
# knn=KNeighborsClassifier()
# sv=SVC()
# nb=GaussianNB()
# dt=DecisionTreeClassifier(random_state=1,criterion= 'gini', max_depth= 9)
# rf=RandomForestClassifier(random_state=1)
# lr=LogisticRegression(C=100)
# models=[knn,sv,nb,dt,rf,lr]
# for model in models:
#     print("*"*25,model,"*"*25)
#     model.fit(X_train,y_train)
#     y_pred=model.predict(X_test)
#     print(classification_report(y_pred,y_test))

# cell 26
# acc = [model.score(X_test, y_test) for model in models]
# df1 = pd.DataFrame({'Algorithm': [model.__class__.__name__ for model in models], 'Accuracy': acc})
# df1['Accuracy'] = df1['Accuracy'].round(2)
# df1 = df1.sort_values(by='Accuracy', ascending=False)
# df1

# cell 27
# plt.figure(figsize=(10, 6))
# plt.title('Accuracy Comparison',fontsize = 25)
# plt.xlabel('Accuracy',fontsize = 15)
# plt.ylabel('Algorithm',fontsize = 15)
# sns.barplot(x='Accuracy', y='Algorithm', data=df1, palette='dark')
# plt.axvline(x=1.0, color='black', linestyle='--')
# plt.axvline(x=0.99, color='black', linestyle='--', ymin=0.001, ymax=0.48)
# plt.axvline(x=0.98, color='black', linestyle='--', ymin=0.0, ymax=0.32)
# plt.xticks([i/10 for i in range(11)])
# plt.savefig('plot.png', dpi=300, bbox_inches='tight')
# plt.show()

# cell 28
# model_pred=[nb,dt,rf]
# for model in model_pred:
#     print("*"*25,model,"*"*25)
#     y_new = np.array([[20, 30, 10, 15, 90, 7.5, 100]])
#     # y_new = np.array([[90,42,43,20.879744,82.002744,6.502985,202.935536]])
#     new_pred = scaler.transform(y_new)
#     new_pred1 = model.predict(new_pred)
#     prediction = le.inverse_transform(new_pred1)
#     print("The Suggested Crop for Given Climatic Condition is:", prediction)
#     print()

# give me all 28 cell code Output describtion for me to add my project.?
# Out:
#   Cell In[1], line 1
#     this is my Machine Learning Project
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 🌾 Crop Recommendation System using ML 🚜
#
# 🔍 Project Overview:
# Developed a Crop Recommendation System using ML algorithms to guide farmers in crop selection based on environmental and soil conditions.
#
# 🛠 Key Libraries Used:
# Pandas, NumPy, Scikit-learn, Matplotlib, Seaborn, LabelEncoder (scikit-learn).
#
# 📊 Exploratory Data Analysis (EDA):
# Explored agricultural dataset, analyzed parameters like Nitrogen, Phosphorous, Potassium, temperature, rainfall, pH, and humidity. Conducted statistical analysis, identified correlations, and created visualizations (heatmaps, countplots, box plots).
#
# 📈 Data Insights:
# Analyzed environmental factors' impact on crop growth using bar plots and count plots. Visualized parameter distributions influencing crop growth.
#
# 📊 Crop Analysis and Comparison:
# Utilized bar plots to compare average Nitrogen (N), Phosphorous (P), and Potassium (K) values for different crops.
#
# 📚 Data Preprocessing:
# Encoded categorical labels with LabelEncoder for ML model preparation.
#
# 🤖 ML Models:
# Trained KNN, SVM, NB, DT, RF, and LR classification models. Evaluated models with classification reports and accuracy scores.
#
# 📈 Model Performance Visualization:
# Created a bar plot to visually compare model accuracies.
#
# 🌐 Deployment:
# Deployed selected models for crop prediction in diverse climatic conditions. Demonstrated model usage for suggesting crops based on user-input parameters.
#
# 🚀 Conclusion:
# Empowering agriculture with data-driven decisions to enhance productivity and sustainability.
#
# 🔗 GitHub Repository: [Link]
# Programming language: #python
# Source: #kaggle
# Guided by: Prajesha TM
# LuminarTechnolab
# #machinelearning
# #datascience
#
#
# 🌱 Let's empower agriculture with data-driven decisions! 🌾🤖

# %% [markdown]
# Project Introduction:
# This project involves the development of a crop recommendation system using machine learning techniques. The goal is to assist farmers in making informed decisions about suitable crops based on various environmental conditions. The dataset used in this project contains information on key factors such as nitrogen, phosphorous, potassium levels, temperature, humidity, pH, and rainfall, along with the corresponding crop labels.
#
# Cell 1: Importing Libraries
# In this cell, essential libraries for data manipulation, visualization, and machine learning are imported. These include pandas, numpy, scikit-learn for machine learning algorithms, and various visualization libraries such as matplotlib and seaborn.
#
# Cell 2: Loading Dataset
# The dataset containing information about environmental conditions and crop labels is loaded from a local file path.
#
# Cell 3: Displaying Dataset Shape
# This cell prints the shape of the dataset, providing information about the number of rows and columns.
#
# Cell 4: Checking for Missing Values
# This cell checks for missing values in the dataset and prints the count of missing values for each column.
#
# Cell 5: Displaying Data Types
# The data types of each column in the dataset are displayed using this cell.
#
# Cell 6: Count of Crops by Label
# This cell displays the count of crops for each unique label in the dataset.
#
# Cell 7: Crop Grouping by Label
# Crop data is grouped by label, and the mean values for each environmental condition are calculated and displayed.
#
# Cell 8: Top 5 Crops Requiring Specific Conditions
# The top 5 crops requiring specific environmental conditions (based on mean values) are displayed for each factor.
#
# Cell 9: Correlation Heatmap
# A heatmap of the correlation matrix is created to visualize the relationships between different environmental factors.
#
# Cell 10: Pairplot for Data Visualization
# A pairplot is generated to visualize the distribution and relationships between pairs of variables, with different colors representing different crop labels.
#
# Cell 11-12: Visualizing Impact of Different Conditions on Crops
# Barplots are created to visualize the impact of Nitrogen, Phosphorous, Potassium, Temperature, Humidity, pH, and Rainfall on different crop labels.
#
# Cell 13: Count Plot for Crop Labels
# A count plot is generated to show the distribution of different crop labels in the dataset.
#
# Cell 14: Distribution Visualization
# Histograms, violin plots, and boxplots are created to visualize the distribution of each environmental condition in the dataset.
#
# Cell 20: Unique Crop Labels
# This cell displays the unique crop labels present in the dataset.
#
# Cell 21-22: Label Encoding Crop Labels
# Crop labels are encoded using LabelEncoder from scikit-learn to convert categorical labels into numerical format.
#
# Cell 23-24: Data Splitting and Scaling
# The dataset is split into training and testing sets, and MinMax scaling is applied to normalize the feature values.
#
# Cell 25: Model Training and Evaluation
# Several machine learning models, including K-Nearest Neighbors, Support Vector Machine, Gaussian Naive Bayes, Decision Tree, Random Forest, and Logistic Regression, are trained and evaluated using the training and testing datasets.
#
# Cell 26-27: Model Accuracy Comparison
# The accuracy of each model is calculated and compared using a bar plot, providing a visual representation of their performance.
#
# Cell 28: Crop Prediction for New Climatic Conditions
# This final cell demonstrates how to use the trained models to predict the most suitable crop for given climatic conditions, using an example input of environmental factors. The predicted crop is then decoded back to its original label using the inverse transformation from LabelEncoder.
